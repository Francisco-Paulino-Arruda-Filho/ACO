# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union
import csv

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    iteracao: int,
    formiga: int,
    best_cost: float,
    current_cost: float,
    tempo_decorrido: float,
    seed: int,
    memoria_usada_MB: float           
) -> None:

    row = [
        instancia,
        iteracao,
        formiga,
        best_cost,
        current_cost,
        tempo_decorrido,
        seed,
        memoria_usada_MB              
    ]

    if any(v is None for v in row):
        return

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido",
        "seed",
        "memoria_usada_MB"            
    ]

    write_header = not os.path.exists(file_name)

    with open(file_name, mode="a", newline="") as f:
        writer = csv.writer(f, quoting=csv.QUOTE_MINIMAL)

        if write_header:
            writer.writerow(header)

        writer.writerow(row)

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None,
    seed: int = None,
    memoria_usada: float = 0.0             
) -> Tuple[List[int], int]:


    n = len(fluxo)
    heuristica = 1 / (np.array(distancia) + 1e-10)
    feromonio = inicializar_feromonio(n)

    melhor_solucao = None
    melhor_custo = float("inf")

    file_name = f"Resultados/iteracoes_{instancia}_ACO.csv"

    if tempo_inicio_global and tempo_global_max:
        if (time.time() - tempo_inicio_global) > tempo_global_max:
            return melhor_solucao or [], int(melhor_custo)

        solucoes = []
        custos = []

        for j in range(n_formigas):

            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor_solucao or [], int(melhor_custo)

            s = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            process = psutil.Process(os.getpid())
            try:
                mem_iter = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                mem_iter = process.memory_info().rss / (1024 * 1024)

            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                iteracao=j,
                formiga=j,
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_decorrido=round(time.time() - tempo_inicio_global, 3),
                seed=seed,
                memoria_usada_MB=round(mem_iter, 2)
            )



        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        process = psutil.Process(os.getpid())
        try:
            mem_iter = process.memory_info().peak_wset / (1024 * 1024)
        except AttributeError:
            mem_iter = process.memory_info().rss / (1024 * 1024)

        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            iteracao=j,
            formiga=j,
            best_cost=melhor_custo,
            current_cost=custo,
            tempo_decorrido=round(time.time() - tempo_inicio_global, 3),
            seed=seed,
            memoria_usada_MB=round(mem_iter, 2)
        )


    return melhor_solucao or [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("Instancias/*.txt")

    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]

        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        rho_value = 0.05 

        for seed in range(42, 52):

            tempo_decorrido_global = time.time() - tempo_inicio_instancia
            if tempo_decorrido_global >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            random.seed(seed)
            np.random.seed(seed)

            process = psutil.Process(os.getpid())
            tempo_inicio_seed = time.time()

            parametros = {
                "n_formigas": 10,
                "alpha": 1.0,
                "beta": 2.0,
                "rho": rho_value,
                "Q": 1,
            }

            melhor_solucao, melhor_custo = aco_qap(
                fluxo=matriz_fluxo,
                distancia=matriz_distancia,
                instancia=nome_instancia,
                tempo_inicio_global=tempo_inicio_instancia,
                tempo_global_max=tempo_global_max,
                seed=seed,             
                **parametros
            )

            tempo_fim_seed = time.time()
            tempo_restante_global = max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
            tempo_execucao = min(tempo_fim_seed - tempo_inicio_seed, tempo_restante_global)

            try:
                memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                memoria_usada = process.memory_info().rss / (1024 * 1024)

            resultados.append({
                "instancia": nome_instancia,
                "seed": seed,
                "rho": rho_value,  
                "melhor_solucao": melhor_solucao,
                "custo": melhor_custo,
                "tempo_execucao_segundos": round(tempo_execucao, 2),
                "memoria_usada_MB": round(memoria_usada, 2),
                **parametros
            })

            print(
                f"[{nome_instancia}] Seed {seed} | rho={rho_value} finalizada. "
                f"Custo: {melhor_custo} | Memória: {round(memoria_usada, 2)} MB"
            )

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"Resultados/resultados_{nome_instancia}_ACO_10min.csv", index=False)

        print(f"\nResultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO_10min.csv")
# Out:
# [Bur26a] Seed 42 | rho=0.05 finalizada. Custo: 5712853 | Memória: 119.75 MB
# [Bur26a] Seed 43 | rho=0.05 finalizada. Custo: 5880902 | Memória: 119.75 MB
# [Bur26a] Seed 44 | rho=0.05 finalizada. Custo: 5898523 | Memória: 119.75 MB
# [Bur26a] Seed 45 | rho=0.05 finalizada. Custo: 5855212 | Memória: 119.75 MB
# [Bur26a] Seed 46 | rho=0.05 finalizada. Custo: 5826164 | Memória: 119.75 MB
# [Bur26a] Seed 47 | rho=0.05 finalizada. Custo: 5928830 | Memória: 119.75 MB
# [Bur26a] Seed 48 | rho=0.05 finalizada. Custo: 5830846 | Memória: 119.75 MB
# [Bur26a] Seed 49 | rho=0.05 finalizada. Custo: 5790129 | Memória: 119.75 MB
# [Bur26a] Seed 50 | rho=0.05 finalizada. Custo: 5856623 | Memória: 119.75 MB
# [Bur26a] Seed 51 | rho=0.05 finalizada. Custo: 5806638 | Memória: 119.75 MB
#
# Resultados da instância Bur26a salvos em resultados_Bur26a_ACO_10min.csv
# [Chr12b] Seed 49 | rho=0.05 finalizada. Custo: 31074 | Memória: 119.75 MB
# [Chr12b] Seed 50 | rho=0.05 finalizada. Custo: 32536 | Memória: 119.75 MB
# [Chr12b] Seed 51 | rho=0.05 finalizada. Custo: 39826 | Memória: 119.75 MB
#
# Resultados da instância Chr12b salvos em resultados_Chr12b_ACO_10min.csv
# [Chr12c] Seed 42 | rho=0.05 finalizada. Custo: 36912 | Memória: 119.75 MB
# [Chr12c] Seed 43 | rho=0.05 finalizada. Custo: 24248 | Memória: 119.75 MB
# [Chr12c] Seed 44 | rho=0.05 finalizada. Custo: 34888 | Memória: 119.75 MB
# [Chr12c] Seed 45 | rho=0.05 finalizada. Custo: 32516 | Memória: 119.75 MB
# [Chr12c] Seed 46 | rho=0.05 finalizada. Custo: 34986 | Memória: 119.75 MB
# [Chr12c] Seed 47 | rho=0.05 finalizada. Custo: 33492 | Memória: 119.75 MB
# [Chr12c] Seed 48 | rho=0.05 finalizada. Custo: 34838 | Memória: 119.75 MB
# [Chr12c] Seed 49 | rho=0.05 finalizada. Custo: 40988 | Memória: 119.75 MB
# [Chr12c] Seed 50 | rho=0.05 finalizada. Custo: 39012 | Memória: 119.75 MB
# [Chr12c] Seed 51 | rho=0.05 finalizada. Custo: 29882 | Memória: 119.75 MB
#
# Resultados da instância Chr12c salvos em resultados_Chr12c_ACO_10min.csv
# [Chr15a] Seed 42 | rho=0.05 finalizada. Custo: 49782 | Memória: 119.75 MB
# [Chr15a] Seed 43 | rho=0.05 finalizada. Custo: 52268 | Memória: 119.75 MB
# [Chr15a] Seed 44 | rho=0.05 finalizada. Custo: 42992 | Memória: 119.75 MB
# [Chr15a] Seed 45 | rho=0.05 finalizada. Custo: 42736 | Memória: 119.75 MB
# [Chr15a] Seed 46 | rho=0.05 finalizada. Custo: 48020 | Memória: 119.75 MB
# [Chr15a] Seed 47 | rho=0.05 finalizada. Custo: 46048 | Memória: 119.75 MB
# [Chr15a] Seed 48 | rho=0.05 finalizada. Custo: 57288 | Memória: 119.75 MB
# [Chr15a] Seed 49 | rho=0.05 finalizada. Custo: 53102 | Memória: 119.75 MB
# [Chr15a] Seed 50 | rho=0.05 finalizada. Custo: 43402 | Memória: 119.75 MB
# [Chr15a] Seed 51 | rho=0.05 finalizada. Custo: 45884 | Memória: 119.75 MB
#
# Resultados da instância Chr15a salvos em resultados_Chr15a_ACO_10min.csv
# [Chr15b] Seed 42 | rho=0.05 finalizada. Custo: 45654 | Memória: 119.75 MB
# [Chr15b] Seed 43 | rho=0.05 finalizada. Custo: 49134 | Memória: 119.75 MB
# [Chr15b] Seed 44 | rho=0.05 finalizada. Custo: 39068 | Memória: 119.75 MB
# [Chr15b] Seed 45 | rho=0.05 finalizada. Custo: 49484 | Memória: 119.75 MB
# [Chr15b] Seed 46 | rho=0.05 finalizada. Custo: 40904 | Memória: 119.75 MB
# [Chr15b] Seed 47 | rho=0.05 finalizada. Custo: 34822 | Memória: 119.75 MB
# [Chr15b] Seed 48 | rho=0.05 finalizada. Custo: 48850 | Memória: 119.75 MB
# [Chr15b] Seed 49 | rho=0.05 finalizada. Custo: 42886 | Memória: 119.75 MB
# [Chr15b] Seed 50 | rho=0.05 finalizada. Custo: 47184 | Memória: 119.75 MB
# [Chr15b] Seed 51 | rho=0.05 finalizada. Custo: 33786 | Memória: 119.75 MB
#
# Resultados da instância Chr15b salvos em resultados_Chr15b_ACO_10min.csv
# [Chr15c] Seed 42 | rho=0.05 finalizada. Custo: 42004 | Memória: 119.75 MB
# [Chr15c] Seed 43 | rho=0.05 finalizada. Custo: 50044 | Memória: 119.75 MB
# [Chr15c] Seed 44 | rho=0.05 finalizada. Custo: 49732 | Memória: 119.75 MB
# [Chr15c] Seed 45 | rho=0.05 finalizada. Custo: 49838 | Memória: 119.75 MB
# [Chr15c] Seed 46 | rho=0.05 finalizada. Custo: 48134 | Memória: 119.75 MB
# [Chr15c] Seed 47 | rho=0.05 finalizada. Custo: 46516 | Memória: 119.75 MB
# [Chr15c] Seed 48 | rho=0.05 finalizada. Custo: 55864 | Memória: 119.75 MB
# [Chr15c] Seed 49 | rho=0.05 finalizada. Custo: 43092 | Memória: 119.75 MB
# [Chr15c] Seed 50 | rho=0.05 finalizada. Custo: 47678 | Memória: 119.75 MB
# [Chr15c] Seed 51 | rho=0.05 finalizada. Custo: 47098 | Memória: 119.75 MB
#
# Resultados da instância Chr15c salvos em resultados_Chr15c_ACO_10min.csv
# [Chr18a] Seed 42 | rho=0.05 finalizada. Custo: 62044 | Memória: 119.75 MB
# [Chr18a] Seed 43 | rho=0.05 finalizada. Custo: 63052 | Memória: 119.75 MB
# [Chr18a] Seed 44 | rho=0.05 finalizada. Custo: 61656 | Memória: 119.75 MB
# [Chr18a] Seed 45 | rho=0.05 finalizada. Custo: 67094 | Memória: 119.75 MB
# [Chr18a] Seed 46 | rho=0.05 finalizada. Custo: 58514 | Memória: 119.75 MB
# [Chr18a] Seed 47 | rho=0.05 finalizada. Custo: 56570 | Memória: 119.75 MB
# [Chr18a] Seed 48 | rho=0.05 finalizada. Custo: 58788 | Memória: 119.75 MB
# [Chr18a] Seed 49 | rho=0.05 finalizada. Custo: 53104 | Memória: 119.75 MB
# [Chr18a] Seed 50 | rho=0.05 finalizada. Custo: 69754 | Memória: 119.75 MB
# [Chr18a] Seed 51 | rho=0.05 finalizada. Custo: 61098 | Memória: 119.75 MB
#
# Resultados da instância Chr18a salvos em resultados_Chr18a_ACO_10min.csv
# [Chr18b] Seed 42 | rho=0.05 finalizada. Custo: 2942 | Memória: 119.75 MB
# [Chr18b] Seed 43 | rho=0.05 finalizada. Custo: 3076 | Memória: 119.75 MB
# [Chr18b] Seed 44 | rho=0.05 finalizada. Custo: 2676 | Memória: 119.75 MB
# [Chr18b] Seed 45 | rho=0.05 finalizada. Custo: 3220 | Memória: 119.75 MB
# [Chr18b] Seed 46 | rho=0.05 finalizada. Custo: 3436 | Memória: 119.75 MB
# [Chr18b] Seed 47 | rho=0.05 finalizada. Custo: 2958 | Memória: 119.75 MB
# [Chr18b] Seed 48 | rho=0.05 finalizada. Custo: 3554 | Memória: 119.75 MB
# [Chr18b] Seed 49 | rho=0.05 finalizada. Custo: 3184 | Memória: 119.75 MB
# [Chr18b] Seed 50 | rho=0.05 finalizada. Custo: 3180 | Memória: 119.75 MB
# [Chr18b] Seed 51 | rho=0.05 finalizada. Custo: 2788 | Memória: 119.75 MB
#
# Resultados da instância Chr18b salvos em resultados_Chr18b_ACO_10min.csv
# [Chr20a] Seed 42 | rho=0.05 finalizada. Custo: 8272 | Memória: 119.75 MB
# [Chr20a] Seed 43 | rho=0.05 finalizada. Custo: 9466 | Memória: 119.75 MB
# [Chr20a] Seed 44 | rho=0.05 finalizada. Custo: 8288 | Memória: 119.75 MB
# [Chr20a] Seed 45 | rho=0.05 finalizada. Custo: 8282 | Memória: 119.75 MB
# [Chr20a] Seed 46 | rho=0.05 finalizada. Custo: 8674 | Memória: 119.75 MB
# [Chr20a] Seed 47 | rho=0.05 finalizada. Custo: 8342 | Memória: 119.75 MB
# [Chr20a] Seed 48 | rho=0.05 finalizada. Custo: 8842 | Memória: 119.75 MB
# [Chr20a] Seed 49 | rho=0.05 finalizada. Custo: 9578 | Memória: 119.75 MB
# [Chr20a] Seed 50 | rho=0.05 finalizada. Custo: 9228 | Memória: 119.75 MB
# [Chr20a] Seed 51 | rho=0.05 finalizada. Custo: 8156 | Memória: 119.75 MB
#
# Resultados da instância Chr20a salvos em resultados_Chr20a_ACO_10min.csv
# [Chr20b] Seed 42 | rho=0.05 finalizada. Custo: 9026 | Memória: 119.75 MB
# [Chr20b] Seed 43 | rho=0.05 finalizada. Custo: 7930 | Memória: 119.75 MB
# [Chr20b] Seed 44 | rho=0.05 finalizada. Custo: 9154 | Memória: 119.75 MB
# [Chr20b] Seed 45 | rho=0.05 finalizada. Custo: 10092 | Memória: 119.75 MB
# [Chr20b] Seed 46 | rho=0.05 finalizada. Custo: 10258 | Memória: 119.75 MB
# [Chr20b] Seed 47 | rho=0.05 finalizada. Custo: 9222 | Memória: 119.75 MB
# [Chr20b] Seed 48 | rho=0.05 finalizada. Custo: 9154 | Memória: 119.75 MB
# [Chr20b] Seed 49 | rho=0.05 finalizada. Custo: 8254 | Memória: 119.75 MB
# [Chr20b] Seed 50 | rho=0.05 finalizada. Custo: 8916 | Memória: 119.75 MB
# [Chr20b] Seed 51 | rho=0.05 finalizada. Custo: 8842 | Memória: 119.75 MB
#
# Resultados da instância Chr20b salvos em resultados_Chr20b_ACO_10min.csv
# [Chr20c] Seed 42 | rho=0.05 finalizada. Custo: 91670 | Memória: 119.75 MB
# [Chr20c] Seed 43 | rho=0.05 finalizada. Custo: 92030 | Memória: 119.75 MB
# [Chr20c] Seed 44 | rho=0.05 finalizada. Custo: 98040 | Memória: 119.75 MB
# [Chr20c] Seed 45 | rho=0.05 finalizada. Custo: 74064 | Memória: 119.75 MB
# [Chr20c] Seed 46 | rho=0.05 finalizada. Custo: 85278 | Memória: 119.75 MB
# [Chr20c] Seed 47 | rho=0.05 finalizada. Custo: 81330 | Memória: 119.75 MB
# [Chr20c] Seed 48 | rho=0.05 finalizada. Custo: 82426 | Memória: 119.75 MB
# [Chr20c] Seed 49 | rho=0.05 finalizada. Custo: 84956 | Memória: 119.75 MB
# [Chr20c] Seed 50 | rho=0.05 finalizada. Custo: 81770 | Memória: 119.75 MB
# [Chr20c] Seed 51 | rho=0.05 finalizada. Custo: 87128 | Memória: 119.75 MB
#
# Resultados da instância Chr20c salvos em resultados_Chr20c_ACO_10min.csv
# [Chr22a] Seed 42 | rho=0.05 finalizada. Custo: 12774 | Memória: 119.75 MB
# [Chr22a] Seed 43 | rho=0.05 finalizada. Custo: 12950 | Memória: 119.75 MB
# [Chr22a] Seed 44 | rho=0.05 finalizada. Custo: 12746 | Memória: 119.75 MB
# [Chr22a] Seed 45 | rho=0.05 finalizada. Custo: 11950 | Memória: 119.75 MB
# [Chr22a] Seed 46 | rho=0.05 finalizada. Custo: 12484 | Memória: 119.75 MB
# [Chr22a] Seed 47 | rho=0.05 finalizada. Custo: 14766 | Memória: 119.75 MB
# [Chr22a] Seed 48 | rho=0.05 finalizada. Custo: 12636 | Memória: 119.75 MB
# [Chr22a] Seed 49 | rho=0.05 finalizada. Custo: 12976 | Memória: 119.75 MB
# [Chr22a] Seed 50 | rho=0.05 finalizada. Custo: 10904 | Memória: 119.75 MB
# [Chr22a] Seed 51 | rho=0.05 finalizada. Custo: 11984 | Memória: 119.75 MB
#
# Resultados da instância Chr22a salvos em resultados_Chr22a_ACO_10min.csv
# [Chr22b] Seed 42 | rho=0.05 finalizada. Custo: 12556 | Memória: 119.75 MB
# [Chr22b] Seed 43 | rho=0.05 finalizada. Custo: 12610 | Memória: 119.75 MB
# [Chr22b] Seed 44 | rho=0.05 finalizada. Custo: 14050 | Memória: 119.75 MB
# [Chr22b] Seed 45 | rho=0.05 finalizada. Custo: 13048 | Memória: 119.75 MB
# [Chr22b] Seed 46 | rho=0.05 finalizada. Custo: 12116 | Memória: 119.75 MB
# [Chr22b] Seed 47 | rho=0.05 finalizada. Custo: 12548 | Memória: 119.75 MB
# [Chr22b] Seed 48 | rho=0.05 finalizada. Custo: 12092 | Memória: 119.75 MB
# [Chr22b] Seed 49 | rho=0.05 finalizada. Custo: 10746 | Memória: 119.75 MB
# [Chr22b] Seed 50 | rho=0.05 finalizada. Custo: 10786 | Memória: 119.75 MB
# [Chr22b] Seed 51 | rho=0.05 finalizada. Custo: 9154 | Memória: 119.75 MB
#
# Resultados da instância Chr22b salvos em resultados_Chr22b_ACO_10min.csv
# [Chr25a] Seed 42 | rho=0.05 finalizada. Custo: 17186 | Memória: 119.75 MB
# [Chr25a] Seed 43 | rho=0.05 finalizada. Custo: 17648 | Memória: 119.75 MB
# [Chr25a] Seed 44 | rho=0.05 finalizada. Custo: 17638 | Memória: 119.75 MB
# [Chr25a] Seed 45 | rho=0.05 finalizada. Custo: 17098 | Memória: 119.75 MB
# [Chr25a] Seed 46 | rho=0.05 finalizada. Custo: 15678 | Memória: 119.75 MB
# [Chr25a] Seed 47 | rho=0.05 finalizada. Custo: 18440 | Memória: 119.75 MB
# [Chr25a] Seed 48 | rho=0.05 finalizada. Custo: 17294 | Memória: 119.75 MB
# [Chr25a] Seed 49 | rho=0.05 finalizada. Custo: 17714 | Memória: 119.75 MB
# [Chr25a] Seed 50 | rho=0.05 finalizada. Custo: 17842 | Memória: 119.75 MB
# [Chr25a] Seed 51 | rho=0.05 finalizada. Custo: 15880 | Memória: 119.75 MB
#
# Resultados da instância Chr25a salvos em resultados_Chr25a_ACO_10min.csv
# [Els19] Seed 42 | rho=0.05 finalizada. Custo: 40645940 | Memória: 119.75 MB
# [Els19] Seed 43 | rho=0.05 finalizada. Custo: 32416936 | Memória: 119.75 MB
# [Els19] Seed 44 | rho=0.05 finalizada. Custo: 45785188 | Memória: 119.75 MB
# [Els19] Seed 45 | rho=0.05 finalizada. Custo: 47008000 | Memória: 119.75 MB
# [Els19] Seed 46 | rho=0.05 finalizada. Custo: 36100862 | Memória: 119.75 MB
# [Els19] Seed 47 | rho=0.05 finalizada. Custo: 37993202 | Memória: 119.75 MB
# [Els19] Seed 48 | rho=0.05 finalizada. Custo: 34564246 | Memória: 119.75 MB
# [Els19] Seed 49 | rho=0.05 finalizada. Custo: 30286628 | Memória: 119.75 MB
# [Els19] Seed 50 | rho=0.05 finalizada. Custo: 43817476 | Memória: 119.75 MB
# [Els19] Seed 51 | rho=0.05 finalizada. Custo: 40695058 | Memória: 119.75 MB
#
# Resultados da instância Els19 salvos em resultados_Els19_ACO_10min.csv
# [Esc128] Seed 42 | rho=0.05 finalizada. Custo: 206 | Memória: 119.75 MB
# [Esc128] Seed 43 | rho=0.05 finalizada. Custo: 190 | Memória: 119.75 MB
# [Esc128] Seed 44 | rho=0.05 finalizada. Custo: 222 | Memória: 119.75 MB
# [Esc128] Seed 45 | rho=0.05 finalizada. Custo: 230 | Memória: 119.75 MB
# [Esc128] Seed 46 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
# [Esc128] Seed 47 | rho=0.05 finalizada. Custo: 226 | Memória: 119.75 MB
# [Esc128] Seed 48 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
# [Esc128] Seed 49 | rho=0.05 finalizada. Custo: 194 | Memória: 119.75 MB
# [Esc128] Seed 50 | rho=0.05 finalizada. Custo: 202 | Memória: 119.75 MB
# [Esc128] Seed 51 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
#
# Resultados da instância Esc128 salvos em resultados_Esc128_ACO_10min.csv
# [Esc16a] Seed 42 | rho=0.05 finalizada. Custo: 84 | Memória: 119.75 MB
# [Esc16a] Seed 43 | rho=0.05 finalizada. Custo: 88 | Memória: 119.75 MB
# [Esc16a] Seed 44 | rho=0.05 finalizada. Custo: 80 | Memória: 119.75 MB
# [Esc16a] Seed 45 | rho=0.05 finalizada. Custo: 84 | Memória: 119.75 MB
# [Esc16a] Seed 46 | rho=0.05 finalizada. Custo: 88 | Memória: 119.75 MB
# [Esc16a] Seed 47 | rho=0.05 finalizada. Custo: 80 | Memória: 119.75 MB
# [Esc16a] Seed 48 | rho=0.05 finalizada. Custo: 80 | Memória: 119.75 MB
# [Esc16a] Seed 49 | rho=0.05 finalizada. Custo: 88 | Memória: 119.75 MB
# [Esc16a] Seed 50 | rho=0.05 finalizada. Custo: 80 | Memória: 119.75 MB
# [Esc16a] Seed 51 | rho=0.05 finalizada. Custo: 92 | Memória: 119.75 MB
#
# Resultados da instância Esc16a salvos em resultados_Esc16a_ACO_10min.csv
# [Esc16b] Seed 42 | rho=0.05 finalizada. Custo: 302 | Memória: 119.75 MB
# [Esc16b] Seed 43 | rho=0.05 finalizada. Custo: 298 | Memória: 119.75 MB
# [Esc16b] Seed 44 | rho=0.05 finalizada. Custo: 298 | Memória: 119.75 MB
# [Esc16b] Seed 45 | rho=0.05 finalizada. Custo: 298 | Memória: 119.75 MB
# [Esc16b] Seed 46 | rho=0.05 finalizada. Custo: 300 | Memória: 119.75 MB
# [Esc16b] Seed 47 | rho=0.05 finalizada. Custo: 302 | Memória: 119.75 MB
# [Esc16b] Seed 48 | rho=0.05 finalizada. Custo: 302 | Memória: 119.75 MB
# [Esc16b] Seed 49 | rho=0.05 finalizada. Custo: 298 | Memória: 119.75 MB
# [Esc16b] Seed 50 | rho=0.05 finalizada. Custo: 300 | Memória: 119.75 MB
# [Esc16b] Seed 51 | rho=0.05 finalizada. Custo: 298 | Memória: 119.75 MB
#
# Resultados da instância Esc16b salvos em resultados_Esc16b_ACO_10min.csv
# [Esc16c] Seed 42 | rho=0.05 finalizada. Custo: 214 | Memória: 119.75 MB
# [Esc16c] Seed 43 | rho=0.05 finalizada. Custo: 212 | Memória: 119.75 MB
# [Esc16c] Seed 44 | rho=0.05 finalizada. Custo: 208 | Memória: 119.75 MB
# [Esc16c] Seed 45 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
# [Esc16c] Seed 46 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
# [Esc16c] Seed 47 | rho=0.05 finalizada. Custo: 188 | Memória: 119.75 MB
# [Esc16c] Seed 48 | rho=0.05 finalizada. Custo: 212 | Memória: 119.75 MB
# [Esc16c] Seed 49 | rho=0.05 finalizada. Custo: 204 | Memória: 119.75 MB
# [Esc16c] Seed 50 | rho=0.05 finalizada. Custo: 208 | Memória: 119.75 MB
# [Esc16c] Seed 51 | rho=0.05 finalizada. Custo: 216 | Memória: 119.75 MB
#
# Resultados da instância Esc16c salvos em resultados_Esc16c_ACO_10min.csv
# [Esc16d] Seed 42 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16d] Seed 43 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16d] Seed 44 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16d] Seed 45 | rho=0.05 finalizada. Custo: 38 | Memória: 119.75 MB
# [Esc16d] Seed 46 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16d] Seed 47 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16d] Seed 48 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16d] Seed 49 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16d] Seed 50 | rho=0.05 finalizada. Custo: 44 | Memória: 119.75 MB
# [Esc16d] Seed 51 | rho=0.05 finalizada. Custo: 38 | Memória: 119.75 MB
#
# Resultados da instância Esc16d salvos em resultados_Esc16d_ACO_10min.csv
# [Esc16e] Seed 42 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16e] Seed 43 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16e] Seed 44 | rho=0.05 finalizada. Custo: 44 | Memória: 119.75 MB
# [Esc16e] Seed 45 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
# [Esc16e] Seed 46 | rho=0.05 finalizada. Custo: 44 | Memória: 119.75 MB
# [Esc16e] Seed 47 | rho=0.05 finalizada. Custo: 44 | Memória: 119.75 MB
# [Esc16e] Seed 48 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16e] Seed 49 | rho=0.05 finalizada. Custo: 48 | Memória: 119.75 MB
# [Esc16e] Seed 50 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16e] Seed 51 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
#
# Resultados da instância Esc16e salvos em resultados_Esc16e_ACO_10min.csv
# [Esc16f] Seed 42 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 43 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 44 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 45 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 46 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 47 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 48 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 49 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 50 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
# [Esc16f] Seed 51 | rho=0.05 finalizada. Custo: 0 | Memória: 119.75 MB
#
# Resultados da instância Esc16f salvos em resultados_Esc16f_ACO_10min.csv
# [Esc16g] Seed 42 | rho=0.05 finalizada. Custo: 32 | Memória: 119.75 MB
# [Esc16g] Seed 43 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16g] Seed 44 | rho=0.05 finalizada. Custo: 48 | Memória: 119.75 MB
# [Esc16g] Seed 45 | rho=0.05 finalizada. Custo: 48 | Memória: 119.75 MB
# [Esc16g] Seed 46 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16g] Seed 47 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16g] Seed 48 | rho=0.05 finalizada. Custo: 40 | Memória: 119.75 MB
# [Esc16g] Seed 49 | rho=0.05 finalizada. Custo: 52 | Memória: 119.75 MB
# [Esc16g] Seed 50 | rho=0.05 finalizada. Custo: 44 | Memória: 119.75 MB
# [Esc16g] Seed 51 | rho=0.05 finalizada. Custo: 36 | Memória: 119.75 MB
#
# Resultados da instância Esc16g salvos em resultados_Esc16g_ACO_10min.csv
# [Esc16h] Seed 42 | rho=0.05 finalizada. Custo: 1080 | Memória: 119.75 MB
# [Esc16h] Seed 43 | rho=0.05 finalizada. Custo: 1016 | Memória: 119.75 MB
# [Esc16h] Seed 44 | rho=0.05 finalizada. Custo: 1064 | Memória: 119.75 MB
# [Esc16h] Seed 45 | rho=0.05 finalizada. Custo: 1012 | Memória: 119.75 MB
# [Esc16h] Seed 46 | rho=0.05 finalizada. Custo: 1076 | Memória: 119.75 MB
# [Esc16h] Seed 47 | rho=0.05 finalizada. Custo: 1056 | Memória: 119.75 MB
# [Esc16h] Seed 48 | rho=0.05 finalizada. Custo: 1056 | Memória: 119.75 MB
# [Esc16h] Seed 49 | rho=0.05 finalizada. Custo: 1066 | Memória: 119.75 MB
# [Esc16h] Seed 50 | rho=0.05 finalizada. Custo: 1072 | Memória: 119.75 MB
# [Esc16h] Seed 51 | rho=0.05 finalizada. Custo: 1116 | Memória: 119.75 MB
#
# Resultados da instância Esc16h salvos em resultados_Esc16h_ACO_10min.csv
# [Esc16i] Seed 42 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 43 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 44 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 45 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 46 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 47 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 48 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 49 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 50 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16i] Seed 51 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
#
# Resultados da instância Esc16i salvos em resultados_Esc16i_ACO_10min.csv
# [Esc16j] Seed 42 | rho=0.05 finalizada. Custo: 22 | Memória: 119.75 MB
# [Esc16j] Seed 43 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16j] Seed 44 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc16j] Seed 45 | rho=0.05 finalizada. Custo: 22 | Memória: 119.75 MB
# [Esc16j] Seed 46 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc16j] Seed 47 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc16j] Seed 48 | rho=0.05 finalizada. Custo: 22 | Memória: 119.75 MB
# [Esc16j] Seed 49 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc16j] Seed 50 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc16j] Seed 51 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
#
# Resultados da instância Esc16j salvos em resultados_Esc16j_ACO_10min.csv
# [Esc32a] Seed 42 | rho=0.05 finalizada. Custo: 370 | Memória: 119.75 MB
# [Esc32a] Seed 43 | rho=0.05 finalizada. Custo: 366 | Memória: 119.75 MB
# [Esc32a] Seed 44 | rho=0.05 finalizada. Custo: 386 | Memória: 119.75 MB
# [Esc32a] Seed 45 | rho=0.05 finalizada. Custo: 378 | Memória: 119.75 MB
# [Esc32a] Seed 46 | rho=0.05 finalizada. Custo: 370 | Memória: 119.75 MB
# [Esc32a] Seed 47 | rho=0.05 finalizada. Custo: 318 | Memória: 119.75 MB
# [Esc32a] Seed 48 | rho=0.05 finalizada. Custo: 378 | Memória: 119.75 MB
# [Esc32a] Seed 49 | rho=0.05 finalizada. Custo: 342 | Memória: 119.75 MB
# [Esc32a] Seed 50 | rho=0.05 finalizada. Custo: 390 | Memória: 119.75 MB
# [Esc32a] Seed 51 | rho=0.05 finalizada. Custo: 354 | Memória: 119.75 MB
#
# Resultados da instância Esc32a salvos em resultados_Esc32a_ACO_10min.csv
# [Esc32b] Seed 42 | rho=0.05 finalizada. Custo: 348 | Memória: 119.75 MB
# [Esc32b] Seed 43 | rho=0.05 finalizada. Custo: 328 | Memória: 119.75 MB
# [Esc32b] Seed 44 | rho=0.05 finalizada. Custo: 328 | Memória: 119.75 MB
# [Esc32b] Seed 45 | rho=0.05 finalizada. Custo: 340 | Memória: 119.75 MB
# [Esc32b] Seed 46 | rho=0.05 finalizada. Custo: 336 | Memória: 119.75 MB
# [Esc32b] Seed 47 | rho=0.05 finalizada. Custo: 324 | Memória: 119.75 MB
# [Esc32b] Seed 48 | rho=0.05 finalizada. Custo: 324 | Memória: 119.75 MB
# [Esc32b] Seed 49 | rho=0.05 finalizada. Custo: 332 | Memória: 119.75 MB
# [Esc32b] Seed 50 | rho=0.05 finalizada. Custo: 320 | Memória: 119.75 MB
# [Esc32b] Seed 51 | rho=0.05 finalizada. Custo: 336 | Memória: 119.75 MB
#
# Resultados da instância Esc32b salvos em resultados_Esc32b_ACO_10min.csv
# [Esc32c] Seed 42 | rho=0.05 finalizada. Custo: 786 | Memória: 119.75 MB
# [Esc32c] Seed 43 | rho=0.05 finalizada. Custo: 770 | Memória: 119.75 MB
# [Esc32c] Seed 44 | rho=0.05 finalizada. Custo: 754 | Memória: 119.75 MB
# [Esc32c] Seed 45 | rho=0.05 finalizada. Custo: 782 | Memória: 119.75 MB
# [Esc32c] Seed 46 | rho=0.05 finalizada. Custo: 790 | Memória: 119.75 MB
# [Esc32c] Seed 47 | rho=0.05 finalizada. Custo: 806 | Memória: 119.75 MB
# [Esc32c] Seed 48 | rho=0.05 finalizada. Custo: 766 | Memória: 119.75 MB
# [Esc32c] Seed 49 | rho=0.05 finalizada. Custo: 758 | Memória: 119.75 MB
# [Esc32c] Seed 50 | rho=0.05 finalizada. Custo: 778 | Memória: 119.75 MB
# [Esc32c] Seed 51 | rho=0.05 finalizada. Custo: 790 | Memória: 119.75 MB
#
# Resultados da instância Esc32c salvos em resultados_Esc32c_ACO_10min.csv
# [Esc32d] Seed 42 | rho=0.05 finalizada. Custo: 300 | Memória: 119.75 MB
# [Esc32d] Seed 43 | rho=0.05 finalizada. Custo: 308 | Memória: 119.75 MB
# [Esc32d] Seed 44 | rho=0.05 finalizada. Custo: 296 | Memória: 119.75 MB
# [Esc32d] Seed 45 | rho=0.05 finalizada. Custo: 292 | Memória: 119.75 MB
# [Esc32d] Seed 46 | rho=0.05 finalizada. Custo: 304 | Memória: 119.75 MB
# [Esc32d] Seed 47 | rho=0.05 finalizada. Custo: 316 | Memória: 119.75 MB
# [Esc32d] Seed 48 | rho=0.05 finalizada. Custo: 292 | Memória: 119.75 MB
# [Esc32d] Seed 49 | rho=0.05 finalizada. Custo: 272 | Memória: 119.75 MB
# [Esc32d] Seed 50 | rho=0.05 finalizada. Custo: 308 | Memória: 119.75 MB
# [Esc32d] Seed 51 | rho=0.05 finalizada. Custo: 312 | Memória: 119.75 MB
#
# Resultados da instância Esc32d salvos em resultados_Esc32d_ACO_10min.csv
# [Esc32e] Seed 42 | rho=0.05 finalizada. Custo: 24 | Memória: 119.75 MB
# [Esc32e] Seed 43 | rho=0.05 finalizada. Custo: 28 | Memória: 119.75 MB
# [Esc32e] Seed 44 | rho=0.05 finalizada. Custo: 24 | Memória: 119.75 MB
# [Esc32e] Seed 45 | rho=0.05 finalizada. Custo: 28 | Memória: 119.75 MB
# [Esc32e] Seed 46 | rho=0.05 finalizada. Custo: 28 | Memória: 119.75 MB
# [Esc32e] Seed 47 | rho=0.05 finalizada. Custo: 28 | Memória: 119.75 MB
# [Esc32e] Seed 48 | rho=0.05 finalizada. Custo: 32 | Memória: 119.75 MB
# [Esc32e] Seed 49 | rho=0.05 finalizada. Custo: 20 | Memória: 119.75 MB
# [Esc32e] Seed 50 | rho=0.05 finalizada. Custo: 24 | Memória: 119.75 MB
# [Esc32e] Seed 51 | rho=0.05 finalizada. Custo: 20 | Memória: 119.75 MB
#
# Resultados da instância Esc32e salvos em resultados_Esc32e_ACO_10min.csv
# [Esc32g] Seed 42 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 43 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 44 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 45 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 46 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 47 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 48 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc32g] Seed 49 | rho=0.05 finalizada. Custo: 14 | Memória: 119.75 MB
# [Esc32g] Seed 50 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
# [Esc32g] Seed 51 | rho=0.05 finalizada. Custo: 18 | Memória: 119.75 MB
#
# Resultados da instância Esc32g salvos em resultados_Esc32g_ACO_10min.csv
# [Esc32h] Seed 42 | rho=0.05 finalizada. Custo: 580 | Memória: 119.75 MB
# [Esc32h] Seed 43 | rho=0.05 finalizada. Custo: 594 | Memória: 119.75 MB
# [Esc32h] Seed 44 | rho=0.05 finalizada. Custo: 574 | Memória: 119.75 MB
# [Esc32h] Seed 45 | rho=0.05 finalizada. Custo: 600 | Memória: 119.75 MB
# [Esc32h] Seed 46 | rho=0.05 finalizada. Custo: 612 | Memória: 119.75 MB
# [Esc32h] Seed 47 | rho=0.05 finalizada. Custo: 604 | Memória: 119.75 MB
# [Esc32h] Seed 48 | rho=0.05 finalizada. Custo: 582 | Memória: 119.75 MB
# [Esc32h] Seed 49 | rho=0.05 finalizada. Custo: 588 | Memória: 119.75 MB
# [Esc32h] Seed 50 | rho=0.05 finalizada. Custo: 600 | Memória: 119.75 MB
# [Esc32h] Seed 51 | rho=0.05 finalizada. Custo: 580 | Memória: 119.75 MB
#
# Resultados da instância Esc32h salvos em resultados_Esc32h_ACO_10min.csv
# [Esc64a] Seed 42 | rho=0.05 finalizada. Custo: 242 | Memória: 119.75 MB
# [Esc64a] Seed 43 | rho=0.05 finalizada. Custo: 238 | Memória: 119.75 MB
# [Esc64a] Seed 44 | rho=0.05 finalizada. Custo: 244 | Memória: 119.75 MB
# [Esc64a] Seed 45 | rho=0.05 finalizada. Custo: 250 | Memória: 119.75 MB
# [Esc64a] Seed 46 | rho=0.05 finalizada. Custo: 234 | Memória: 119.75 MB
# [Esc64a] Seed 47 | rho=0.05 finalizada. Custo: 218 | Memória: 119.75 MB
# [Esc64a] Seed 48 | rho=0.05 finalizada. Custo: 222 | Memória: 119.75 MB
# [Esc64a] Seed 49 | rho=0.05 finalizada. Custo: 226 | Memória: 119.75 MB
# [Esc64a] Seed 50 | rho=0.05 finalizada. Custo: 242 | Memória: 119.75 MB
# [Esc64a] Seed 51 | rho=0.05 finalizada. Custo: 246 | Memória: 119.75 MB
#
# Resultados da instância Esc64a salvos em resultados_Esc64a_ACO_10min.csv
# [Had12] Seed 42 | rho=0.05 finalizada. Custo: 1830 | Memória: 119.75 MB
# [Had12] Seed 43 | rho=0.05 finalizada. Custo: 1842 | Memória: 119.75 MB
# [Had12] Seed 44 | rho=0.05 finalizada. Custo: 1860 | Memória: 119.75 MB
# [Had12] Seed 45 | rho=0.05 finalizada. Custo: 1888 | Memória: 119.75 MB
# [Had12] Seed 46 | rho=0.05 finalizada. Custo: 1828 | Memória: 119.75 MB
# [Had12] Seed 47 | rho=0.05 finalizada. Custo: 1842 | Memória: 119.75 MB
# [Had12] Seed 48 | rho=0.05 finalizada. Custo: 1836 | Memória: 119.75 MB
# [Had12] Seed 49 | rho=0.05 finalizada. Custo: 1768 | Memória: 119.75 MB
# [Had12] Seed 50 | rho=0.05 finalizada. Custo: 1836 | Memória: 119.75 MB
# [Had12] Seed 51 | rho=0.05 finalizada. Custo: 1858 | Memória: 119.75 MB
#
# Resultados da instância Had12 salvos em resultados_Had12_ACO_10min.csv
# [Had14] Seed 42 | rho=0.05 finalizada. Custo: 3124 | Memória: 119.75 MB
# [Had14] Seed 43 | rho=0.05 finalizada. Custo: 3146 | Memória: 119.75 MB
# [Had14] Seed 44 | rho=0.05 finalizada. Custo: 3108 | Memória: 119.75 MB
# [Had14] Seed 45 | rho=0.05 finalizada. Custo: 3068 | Memória: 119.75 MB
# [Had14] Seed 46 | rho=0.05 finalizada. Custo: 3120 | Memória: 119.75 MB
# [Had14] Seed 47 | rho=0.05 finalizada. Custo: 3120 | Memória: 119.75 MB
# [Had14] Seed 48 | rho=0.05 finalizada. Custo: 3068 | Memória: 119.75 MB
# [Had14] Seed 49 | rho=0.05 finalizada. Custo: 3204 | Memória: 119.75 MB
# [Had14] Seed 50 | rho=0.05 finalizada. Custo: 3142 | Memória: 119.75 MB
# [Had14] Seed 51 | rho=0.05 finalizada. Custo: 3136 | Memória: 119.75 MB
#
# Resultados da instância Had14 salvos em resultados_Had14_ACO_10min.csv
# [Had16] Seed 42 | rho=0.05 finalizada. Custo: 4166 | Memória: 119.75 MB
# [Had16] Seed 43 | rho=0.05 finalizada. Custo: 4250 | Memória: 119.75 MB
# [Had16] Seed 44 | rho=0.05 finalizada. Custo: 4196 | Memória: 119.75 MB
# [Had16] Seed 45 | rho=0.05 finalizada. Custo: 4156 | Memória: 119.75 MB
# [Had16] Seed 46 | rho=0.05 finalizada. Custo: 4182 | Memória: 119.75 MB
# [Had16] Seed 47 | rho=0.05 finalizada. Custo: 4146 | Memória: 119.75 MB
# [Had16] Seed 48 | rho=0.05 finalizada. Custo: 4272 | Memória: 119.75 MB
# [Had16] Seed 49 | rho=0.05 finalizada. Custo: 4128 | Memória: 119.75 MB
# [Had16] Seed 50 | rho=0.05 finalizada. Custo: 4120 | Memória: 119.75 MB
# [Had16] Seed 51 | rho=0.05 finalizada. Custo: 4138 | Memória: 119.75 MB
#
# Resultados da instância Had16 salvos em resultados_Had16_ACO_10min.csv
# [Had18] Seed 42 | rho=0.05 finalizada. Custo: 6060 | Memória: 119.75 MB
# [Had18] Seed 43 | rho=0.05 finalizada. Custo: 5918 | Memória: 119.75 MB
# [Had18] Seed 44 | rho=0.05 finalizada. Custo: 5924 | Memória: 119.75 MB
# [Had18] Seed 45 | rho=0.05 finalizada. Custo: 6000 | Memória: 119.75 MB
# [Had18] Seed 46 | rho=0.05 finalizada. Custo: 5966 | Memória: 119.75 MB
# [Had18] Seed 47 | rho=0.05 finalizada. Custo: 5912 | Memória: 119.75 MB
# [Had18] Seed 48 | rho=0.05 finalizada. Custo: 5894 | Memória: 119.75 MB
# [Had18] Seed 49 | rho=0.05 finalizada. Custo: 5956 | Memória: 119.75 MB
# [Had18] Seed 50 | rho=0.05 finalizada. Custo: 5884 | Memória: 119.75 MB
# [Had18] Seed 51 | rho=0.05 finalizada. Custo: 6062 | Memória: 119.75 MB
#
# Resultados da instância Had18 salvos em resultados_Had18_ACO_10min.csv
# [Had20] Seed 42 | rho=0.05 finalizada. Custo: 7612 | Memória: 119.75 MB
# [Had20] Seed 43 | rho=0.05 finalizada. Custo: 7658 | Memória: 119.75 MB
# [Had20] Seed 44 | rho=0.05 finalizada. Custo: 7780 | Memória: 119.75 MB
# [Had20] Seed 45 | rho=0.05 finalizada. Custo: 7624 | Memória: 119.75 MB
# [Had20] Seed 46 | rho=0.05 finalizada. Custo: 7624 | Memória: 119.75 MB
# [Had20] Seed 47 | rho=0.05 finalizada. Custo: 7782 | Memória: 119.75 MB
# [Lipa30a] Seed 46 | rho=0.05 finalizada. Custo: 13753 | Memória: 119.75 MB
# [Lipa30a] Seed 47 | rho=0.05 finalizada. Custo: 13771 | Memória: 119.75 MB
# [Lipa30a] Seed 48 | rho=0.05 finalizada. Custo: 13737 | Memória: 119.75 MB
# [Lipa30a] Seed 49 | rho=0.05 finalizada. Custo: 13786 | Memória: 119.75 MB
# [Lipa30a] Seed 50 | rho=0.05 finalizada. Custo: 13778 | Memória: 119.75 MB
# [Lipa30a] Seed 51 | rho=0.05 finalizada. Custo: 13777 | Memória: 119.75 MB
#
# Resultados da instância Lipa30a salvos em resultados_Lipa30a_ACO_10min.csv
# [Lipa30b] Seed 42 | rho=0.05 finalizada. Custo: 192620 | Memória: 119.75 MB
# [Lipa30b] Seed 43 | rho=0.05 finalizada. Custo: 191356 | Memória: 119.75 MB
# [Lipa30b] Seed 44 | rho=0.05 finalizada. Custo: 191163 | Memória: 119.75 MB
# [Lipa30b] Seed 45 | rho=0.05 finalizada. Custo: 193736 | Memória: 119.75 MB
# [Lipa30b] Seed 46 | rho=0.05 finalizada. Custo: 191309 | Memória: 119.75 MB
# [Lipa30b] Seed 47 | rho=0.05 finalizada. Custo: 194279 | Memória: 119.75 MB
# [Lipa30b] Seed 48 | rho=0.05 finalizada. Custo: 192370 | Memória: 119.75 MB
# [Lipa30b] Seed 49 | rho=0.05 finalizada. Custo: 192960 | Memória: 119.75 MB
# [Lipa30b] Seed 50 | rho=0.05 finalizada. Custo: 193646 | Memória: 119.75 MB
# [Lipa30b] Seed 51 | rho=0.05 finalizada. Custo: 192643 | Memória: 119.75 MB
#
# Resultados da instância Lipa30b salvos em resultados_Lipa30b_ACO_10min.csv
# [Lipa40a] Seed 42 | rho=0.05 finalizada. Custo: 32586 | Memória: 119.75 MB
# [Lipa40a] Seed 43 | rho=0.05 finalizada. Custo: 32555 | Memória: 119.75 MB
# [Lipa40a] Seed 44 | rho=0.05 finalizada. Custo: 32547 | Memória: 119.75 MB
# [Lipa40a] Seed 45 | rho=0.05 finalizada. Custo: 32650 | Memória: 119.75 MB
# [Lipa40a] Seed 46 | rho=0.05 finalizada. Custo: 32526 | Memória: 119.75 MB
# [Lipa40a] Seed 47 | rho=0.05 finalizada. Custo: 32618 | Memória: 119.75 MB
# [Lipa40a] Seed 48 | rho=0.05 finalizada. Custo: 32620 | Memória: 119.75 MB
# [Lipa40a] Seed 49 | rho=0.05 finalizada. Custo: 32626 | Memória: 119.75 MB
# [Lipa40a] Seed 50 | rho=0.05 finalizada. Custo: 32626 | Memória: 119.75 MB
# [Lipa40a] Seed 51 | rho=0.05 finalizada. Custo: 32537 | Memória: 119.75 MB
#
# Resultados da instância Lipa40a salvos em resultados_Lipa40a_ACO_10min.csv
# [Lipa40b] Seed 42 | rho=0.05 finalizada. Custo: 611848 | Memória: 119.75 MB
# [Lipa40b] Seed 43 | rho=0.05 finalizada. Custo: 608398 | Memória: 119.75 MB
# [Lipa40b] Seed 44 | rho=0.05 finalizada. Custo: 620153 | Memória: 119.75 MB
# [Lipa40b] Seed 45 | rho=0.05 finalizada. Custo: 610458 | Memória: 119.75 MB
# [Lipa40b] Seed 46 | rho=0.05 finalizada. Custo: 608543 | Memória: 119.75 MB
# [Lipa40b] Seed 47 | rho=0.05 finalizada. Custo: 610291 | Memória: 119.75 MB
# [Lipa40b] Seed 48 | rho=0.05 finalizada. Custo: 612950 | Memória: 119.75 MB
# [Lipa40b] Seed 49 | rho=0.05 finalizada. Custo: 610486 | Memória: 119.75 MB
# [Lipa40b] Seed 50 | rho=0.05 finalizada. Custo: 615712 | Memória: 119.75 MB
# [Lipa40b] Seed 51 | rho=0.05 finalizada. Custo: 611535 | Memória: 119.75 MB
#
# Resultados da instância Lipa40b salvos em resultados_Lipa40b_ACO_10min.csv
# [Lipa50a] Seed 42 | rho=0.05 finalizada. Custo: 63897 | Memória: 119.75 MB
# [Lipa50a] Seed 43 | rho=0.05 finalizada. Custo: 63839 | Memória: 119.75 MB
# [Lipa50a] Seed 44 | rho=0.05 finalizada. Custo: 63912 | Memória: 119.75 MB
# [Lipa50a] Seed 45 | rho=0.05 finalizada. Custo: 63910 | Memória: 119.75 MB
# [Lipa50a] Seed 46 | rho=0.05 finalizada. Custo: 63943 | Memória: 119.75 MB
# [Lipa50a] Seed 47 | rho=0.05 finalizada. Custo: 63999 | Memória: 119.75 MB
# [Lipa50a] Seed 48 | rho=0.05 finalizada. Custo: 63937 | Memória: 119.75 MB
# [Lipa50a] Seed 49 | rho=0.05 finalizada. Custo: 63844 | Memória: 119.75 MB
# [Lipa50a] Seed 50 | rho=0.05 finalizada. Custo: 63863 | Memória: 119.75 MB
# [Lipa50a] Seed 51 | rho=0.05 finalizada. Custo: 63829 | Memória: 119.75 MB
#
# Resultados da instância Lipa50a salvos em resultados_Lipa50a_ACO_10min.csv
# [Lipa50b] Seed 42 | rho=0.05 finalizada. Custo: 1541210 | Memória: 119.75 MB
# [Lipa50b] Seed 43 | rho=0.05 finalizada. Custo: 1549164 | Memória: 119.75 MB
# [Lipa50b] Seed 44 | rho=0.05 finalizada. Custo: 1547451 | Memória: 119.75 MB
# [Lipa50b] Seed 45 | rho=0.05 finalizada. Custo: 1537321 | Memória: 119.75 MB
# [Lipa50b] Seed 46 | rho=0.05 finalizada. Custo: 1542630 | Memória: 119.75 MB
# [Lipa50b] Seed 47 | rho=0.05 finalizada. Custo: 1551065 | Memória: 119.75 MB
# [Lipa50b] Seed 48 | rho=0.05 finalizada. Custo: 1552290 | Memória: 119.75 MB
# [Lipa50b] Seed 49 | rho=0.05 finalizada. Custo: 1546778 | Memória: 119.75 MB
# [Lipa50b] Seed 50 | rho=0.05 finalizada. Custo: 1547712 | Memória: 119.75 MB
# [Lipa50b] Seed 51 | rho=0.05 finalizada. Custo: 1544628 | Memória: 119.75 MB
#
# Resultados da instância Lipa50b salvos em resultados_Lipa50b_ACO_10min.csv
# [Lipa60a] Seed 42 | rho=0.05 finalizada. Custo: 109911 | Memória: 119.75 MB
# [Tai25b] Seed 49 | rho=0.05 finalizada. Custo: 747873371 | Memória: 119.75 MB
# [Tai25b] Seed 50 | rho=0.05 finalizada. Custo: 716811109 | Memória: 119.75 MB
# [Tai25b] Seed 51 | rho=0.05 finalizada. Custo: 598975725 | Memória: 119.75 MB
#
# Resultados da instância Tai25b salvos em resultados_Tai25b_ACO_10min.csv
# [Tai30a] Seed 42 | rho=0.05 finalizada. Custo: 2157902 | Memória: 119.75 MB
# [Tai30a] Seed 43 | rho=0.05 finalizada. Custo: 2177212 | Memória: 119.75 MB
# [Tai30a] Seed 44 | rho=0.05 finalizada. Custo: 2126956 | Memória: 119.75 MB
# [Tai30a] Seed 45 | rho=0.05 finalizada. Custo: 2180428 | Memória: 119.75 MB
# [Tai30a] Seed 46 | rho=0.05 finalizada. Custo: 2194162 | Memória: 119.75 MB
# [Tai30a] Seed 47 | rho=0.05 finalizada. Custo: 2118026 | Memória: 119.75 MB
# [Tai30a] Seed 48 | rho=0.05 finalizada. Custo: 2175770 | Memória: 119.75 MB
# [Tai30a] Seed 49 | rho=0.05 finalizada. Custo: 2172726 | Memória: 119.75 MB
# [Tai30a] Seed 50 | rho=0.05 finalizada. Custo: 2133494 | Memória: 119.75 MB
# [Tai30a] Seed 51 | rho=0.05 finalizada. Custo: 2171404 | Memória: 119.75 MB
#
# Resultados da instância Tai30a salvos em resultados_Tai30a_ACO_10min.csv
# [Tai30b] Seed 42 | rho=0.05 finalizada. Custo: 1202133696 | Memória: 119.75 MB
# [Tai30b] Seed 43 | rho=0.05 finalizada. Custo: 1225852711 | Memória: 119.75 MB
# [Tai30b] Seed 44 | rho=0.05 finalizada. Custo: 1207414793 | Memória: 119.75 MB
# [Tai30b] Seed 45 | rho=0.05 finalizada. Custo: 1261843194 | Memória: 119.75 MB
# [Tai30b] Seed 46 | rho=0.05 finalizada. Custo: 1201167593 | Memória: 119.75 MB
# [Tai30b] Seed 47 | rho=0.05 finalizada. Custo: 1166813271 | Memória: 119.75 MB
# [Tai30b] Seed 48 | rho=0.05 finalizada. Custo: 1104601797 | Memória: 119.75 MB
# [Tai30b] Seed 49 | rho=0.05 finalizada. Custo: 1085024129 | Memória: 119.75 MB
# [Tai30b] Seed 50 | rho=0.05 finalizada. Custo: 1149321536 | Memória: 119.75 MB
# [Tai30b] Seed 51 | rho=0.05 finalizada. Custo: 1181056194 | Memória: 119.75 MB
#
# Resultados da instância Tai30b salvos em resultados_Tai30b_ACO_10min.csv
# [Tai35a] Seed 42 | rho=0.05 finalizada. Custo: 2867874 | Memória: 119.75 MB
# [Tai35a] Seed 43 | rho=0.05 finalizada. Custo: 2912376 | Memória: 119.75 MB
# [Tai35a] Seed 44 | rho=0.05 finalizada. Custo: 2869926 | Memória: 119.75 MB
# [Tai35a] Seed 45 | rho=0.05 finalizada. Custo: 2903278 | Memória: 119.75 MB
# [Tai35a] Seed 46 | rho=0.05 finalizada. Custo: 2830768 | Memória: 119.75 MB
# [Tai35a] Seed 47 | rho=0.05 finalizada. Custo: 2883490 | Memória: 119.75 MB
# [Tai35a] Seed 48 | rho=0.05 finalizada. Custo: 2865570 | Memória: 119.75 MB
# [Tai35a] Seed 49 | rho=0.05 finalizada. Custo: 2899394 | Memória: 119.75 MB
# [Tai35a] Seed 50 | rho=0.05 finalizada. Custo: 2863950 | Memória: 119.75 MB
# [Tai35a] Seed 51 | rho=0.05 finalizada. Custo: 2889526 | Memória: 119.75 MB
#
# Resultados da instância Tai35a salvos em resultados_Tai35a_ACO_10min.csv
# [Tai35b] Seed 42 | rho=0.05 finalizada. Custo: 461983372 | Memória: 119.75 MB
# [Tai35b] Seed 43 | rho=0.05 finalizada. Custo: 468338458 | Memória: 119.75 MB
# [Tai35b] Seed 44 | rho=0.05 finalizada. Custo: 517356755 | Memória: 119.75 MB
# [Tai35b] Seed 45 | rho=0.05 finalizada. Custo: 460153253 | Memória: 119.75 MB
# [Tai35b] Seed 46 | rho=0.05 finalizada. Custo: 462544138 | Memória: 119.75 MB
# [Tai35b] Seed 47 | rho=0.05 finalizada. Custo: 501487769 | Memória: 119.75 MB
# [Tai35b] Seed 48 | rho=0.05 finalizada. Custo: 493686532 | Memória: 119.75 MB
# [Tai35b] Seed 49 | rho=0.05 finalizada. Custo: 502701690 | Memória: 119.75 MB
# [Tai35b] Seed 50 | rho=0.05 finalizada. Custo: 504017726 | Memória: 119.75 MB
# [Tai35b] Seed 51 | rho=0.05 finalizada. Custo: 483828321 | Memória: 119.75 MB
#
# Resultados da instância Tai35b salvos em resultados_Tai35b_ACO_10min.csv
# [Tai40a] Seed 42 | rho=0.05 finalizada. Custo: 3685646 | Memória: 119.75 MB
# [Tai40a] Seed 43 | rho=0.05 finalizada. Custo: 3650756 | Memória: 119.75 MB
# [Tai40a] Seed 44 | rho=0.05 finalizada. Custo: 3622156 | Memória: 119.75 MB
# [Tai40a] Seed 45 | rho=0.05 finalizada. Custo: 3656318 | Memória: 119.75 MB
# [Tai40a] Seed 46 | rho=0.05 finalizada. Custo: 3704690 | Memória: 119.75 MB
# [Tai40a] Seed 47 | rho=0.05 finalizada. Custo: 3688332 | Memória: 119.75 MB
# [Tai40a] Seed 48 | rho=0.05 finalizada. Custo: 3698136 | Memória: 119.75 MB
# [Tai40a] Seed 49 | rho=0.05 finalizada. Custo: 3674494 | Memória: 119.75 MB
# [Tai40a] Seed 50 | rho=0.05 finalizada. Custo: 3686488 | Memória: 119.75 MB
# [Tai40a] Seed 51 | rho=0.05 finalizada. Custo: 3681878 | Memória: 119.75 MB
#
# Resultados da instância Tai40a salvos em resultados_Tai40a_ACO_10min.csv
# [Tai40b] Seed 42 | rho=0.05 finalizada. Custo: 1098840311 | Memória: 119.75 MB
# [Tai40b] Seed 43 | rho=0.05 finalizada. Custo: 1089818094 | Memória: 119.75 MB
# [Tai40b] Seed 44 | rho=0.05 finalizada. Custo: 969568686 | Memória: 119.75 MB
# [Tai40b] Seed 45 | rho=0.05 finalizada. Custo: 1059179464 | Memória: 119.75 MB
# [Tai40b] Seed 46 | rho=0.05 finalizada. Custo: 1103210076 | Memória: 119.75 MB
# [Tai40b] Seed 47 | rho=0.05 finalizada. Custo: 1110572549 | Memória: 119.75 MB
# [Tai40b] Seed 48 | rho=0.05 finalizada. Custo: 1104562260 | Memória: 119.75 MB
# [Tai40b] Seed 49 | rho=0.05 finalizada. Custo: 1096187734 | Memória: 119.75 MB
# [Tai40b] Seed 50 | rho=0.05 finalizada. Custo: 1038157755 | Memória: 119.75 MB
# [Tai40b] Seed 51 | rho=0.05 finalizada. Custo: 1036512195 | Memória: 119.75 MB
#
# Resultados da instância Tai40b salvos em resultados_Tai40b_ACO_10min.csv
# [Tai50a] Seed 42 | rho=0.05 finalizada. Custo: 5833150 | Memória: 119.75 MB
# [Tai50a] Seed 43 | rho=0.05 finalizada. Custo: 5827000 | Memória: 119.75 MB
# [Tai50a] Seed 44 | rho=0.05 finalizada. Custo: 5828870 | Memória: 119.75 MB
# [Tai50a] Seed 45 | rho=0.05 finalizada. Custo: 5856476 | Memória: 119.75 MB
# [Tai50a] Seed 46 | rho=0.05 finalizada. Custo: 5706852 | Memória: 119.75 MB
# [Tai50a] Seed 47 | rho=0.05 finalizada. Custo: 5826544 | Memória: 119.75 MB
# [Tai50a] Seed 48 | rho=0.05 finalizada. Custo: 5833992 | Memória: 119.75 MB
# [Tai50a] Seed 49 | rho=0.05 finalizada. Custo: 5760680 | Memória: 119.75 MB
# [Tai50a] Seed 50 | rho=0.05 finalizada. Custo: 5763414 | Memória: 119.75 MB
# [Tai50a] Seed 51 | rho=0.05 finalizada. Custo: 5724704 | Memória: 119.75 MB
#
# Resultados da instância Tai50a salvos em resultados_Tai50a_ACO_10min.csv
# [Tai50b] Seed 42 | rho=0.05 finalizada. Custo: 716561540 | Memória: 119.75 MB
# [Tai50b] Seed 43 | rho=0.05 finalizada. Custo: 740688342 | Memória: 119.75 MB
# [Tai50b] Seed 44 | rho=0.05 finalizada. Custo: 743662038 | Memória: 119.75 MB
# [Tai50b] Seed 45 | rho=0.05 finalizada. Custo: 767134053 | Memória: 119.75 MB
# [Tai50b] Seed 46 | rho=0.05 finalizada. Custo: 718193276 | Memória: 119.75 MB
# [Tai50b] Seed 47 | rho=0.05 finalizada. Custo: 690269720 | Memória: 119.75 MB
# [Tai50b] Seed 48 | rho=0.05 finalizada. Custo: 776778155 | Memória: 119.75 MB
# [Tai50b] Seed 49 | rho=0.05 finalizada. Custo: 693845754 | Memória: 119.75 MB
# [Tai50b] Seed 50 | rho=0.05 finalizada. Custo: 760781642 | Memória: 119.75 MB
# [Tai50b] Seed 51 | rho=0.05 finalizada. Custo: 761668898 | Memória: 119.75 MB
#
# Resultados da instância Tai50b salvos em resultados_Tai50b_ACO_10min.csv
# [Tai60a] Seed 42 | rho=0.05 finalizada. Custo: 8420538 | Memória: 119.75 MB
# [Tai60a] Seed 43 | rho=0.05 finalizada. Custo: 8383852 | Memória: 119.75 MB
