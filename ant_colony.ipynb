# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union
import csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 import random
# ----> 3 import pandas as pd
#       4 import psutil
#       5 import os
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
#      76     IntervalDtype,
#      77     DatetimeTZDtype,
#      78     StringDtype,
#      79     BooleanDtype,
#      80     # missing
#      81     NA,
#      82     isna,
#      83     isnull,
#      84     notna,
#      85     notnull,
#      86     # indexes
#      87     Index,
#      88     CategoricalIndex,
#      89     RangeIndex,
#      90     MultiIndex,
#      91     IntervalIndex,
#      92     TimedeltaIndex,
#      93     DatetimeIndex,
#      94     PeriodIndex,
#      95     IndexSlice,
#      96     # tseries
#      97     NaT,
#      98     Period,
#      99     period_range,
#     100     Timedelta,
#     101     timedelta_range,
#     102     Timestamp,
#     103     date_range,
#     104     bdate_range,
#     105     Interval,
#     106     interval_range,
#     107     DateOffset,
#     108     # conversion
#     109     to_numeric,
#     110     to_datetime,
#     111     to_timedelta,
#     112     # misc
#     113     Flags,
#     114     Grouper,
#     115     factorize,
#     116     unique,
#     117     value_counts,
#     118     NamedAgg,
#     119     array,
#     120     Categorical,
#     121     set_eng_float_format,
#     122     Series,
#     123     DataFrame,
#     124 )
#     126 from pandas.core.dtypes.dtypes import SparseDtype
#     128 from pandas.tseries.api import infer_freq
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File pandas/_libs/missing.pyx:40, in init pandas._libs.missing()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 print(pd.__version__)
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
#      76     IntervalDtype,
#      77     DatetimeTZDtype,
#      78     StringDtype,
#      79     BooleanDtype,
#      80     # missing
#      81     NA,
#      82     isna,
#      83     isnull,
#      84     notna,
#      85     notnull,
#      86     # indexes
#      87     Index,
#      88     CategoricalIndex,
#      89     RangeIndex,
#      90     MultiIndex,
#      91     IntervalIndex,
#      92     TimedeltaIndex,
#      93     DatetimeIndex,
#      94     PeriodIndex,
#      95     IndexSlice,
#      96     # tseries
#      97     NaT,
#      98     Period,
#      99     period_range,
#     100     Timedelta,
#     101     timedelta_range,
#     102     Timestamp,
#     103     date_range,
#     104     bdate_range,
#     105     Interval,
#     106     interval_range,
#     107     DateOffset,
#     108     # conversion
#     109     to_numeric,
#     110     to_datetime,
#     111     to_timedelta,
#     112     # misc
#     113     Flags,
#     114     Grouper,
#     115     factorize,
#     116     unique,
#     117     value_counts,
#     118     NamedAgg,
#     119     array,
#     120     Categorical,
#     121     set_eng_float_format,
#     122     Series,
#     123     DataFrame,
#     124 )
#     126 from pandas.core.dtypes.dtypes import SparseDtype
#     128 from pandas.tseries.api import infer_freq
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File c:\Users\fpaul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File pandas/_libs/missing.pyx:40, in init pandas._libs.missing()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    iteracao: int,
    formiga: int,
    best_cost: float,
    current_cost: float,
    tempo_decorrido: float
) -> None:
    """
    Salva resultados parciais da execução do ACO em um arquivo CSV.
    """

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido"
    ]

    write_header = not os.path.exists(file_name)

    with open(file_name, mode="a", newline="") as f:
        writer = csv.writer(f)

        if write_header:
            writer.writerow(header)

        writer.writerow([
            instancia,
            iteracao,
            formiga,
            best_cost,
            current_cost,
            tempo_decorrido
        ])

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None
) -> Tuple[List[int], int]:

    n = len(fluxo)
    heuristica = 1 / (np.array(distancia) + 1e-10)
    feromonio = inicializar_feromonio(n)

    melhor_solucao = None
    melhor_custo = float("inf")

    file_name = f"Resultados/iteracoes_{instancia}_ACO.csv"

    if tempo_inicio_global and tempo_global_max:
        if (time.time() - tempo_inicio_global) > tempo_global_max:
            return melhor_solucao or [], int(melhor_custo)

        solucoes = []
        custos = []

        for j in range(n_formigas):

            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor_solucao or [], int(melhor_custo)

            s = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                iteracao=j,            # <--- corrigido
                formiga=j,             # <--- corrigido
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_decorrido=round(time.time() - tempo_inicio_global, 3)
            )

        # Atualização global do feromônio
        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            iteracao=-1,             # <--- marca agregada
            formiga=-1,
            best_cost=melhor_custo,
            current_cost=min(custos),
            tempo_decorrido=round(time.time() - tempo_inicio_global, 3)
        )

    return melhor_solucao or [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("Instancias/*.txt")

    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]

        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        rho_value = 0.05 

        for seed in range(42, 52):

            tempo_decorrido_global = time.time() - tempo_inicio_instancia
            if tempo_decorrido_global >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            random.seed(seed)
            np.random.seed(seed)

            process = psutil.Process(os.getpid())
            tempo_inicio_seed = time.time()

            parametros = {
                "n_formigas": 10,
                "alpha": 1.0,
                "beta": 2.0,
                "rho": rho_value,
                "Q": 1,
            }

            melhor_solucao, melhor_custo = aco_qap(
                fluxo=matriz_fluxo,
                distancia=matriz_distancia,
                instancia=nome_instancia,
                tempo_inicio_global=tempo_inicio_instancia,
                tempo_global_max=tempo_global_max,
                **parametros
            )

            tempo_fim_seed = time.time()

            tempo_restante_global = max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
            tempo_execucao = min(tempo_fim_seed - tempo_inicio_seed, tempo_restante_global)

            try:
                memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                memoria_usada = process.memory_info().rss / (1024 * 1024)

            resultados.append({
                "instancia": nome_instancia,
                "seed": seed,
                "rho": rho_value,  
                "melhor_solucao": melhor_solucao,
                "custo": melhor_custo,
                "tempo_execucao_segundos": round(tempo_execucao, 2),
                "memoria_usada_MB": round(memoria_usada, 2),
                **parametros
            })

            print(
                f"[{nome_instancia}] Seed {seed} | rho={rho_value} finalizada. "
                f"Custo: {melhor_custo} | Memória: {round(memoria_usada, 2)} MB"
            )

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"Resultados/resultados_{nome_instancia}_ACO_10min.csv", index=False)

        print(f"\nResultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO_10min.csv")
# Out:
# [Tai100a] Seed 42 | rho=0.05 finalizada. Custo: 23945672 | Memória: 121.13 MB
# [Tai100a] Seed 43 | rho=0.05 finalizada. Custo: 23968038 | Memória: 121.13 MB
# [Tai100a] Seed 44 | rho=0.05 finalizada. Custo: 23912796 | Memória: 121.13 MB
# [Tai100a] Seed 45 | rho=0.05 finalizada. Custo: 23959862 | Memória: 121.13 MB
# [Tai100a] Seed 46 | rho=0.05 finalizada. Custo: 24011942 | Memória: 121.13 MB
# [Tai100a] Seed 47 | rho=0.05 finalizada. Custo: 23998222 | Memória: 121.13 MB
# [Tai100a] Seed 48 | rho=0.05 finalizada. Custo: 23964654 | Memória: 121.13 MB
# [Tai100a] Seed 49 | rho=0.05 finalizada. Custo: 23924524 | Memória: 121.13 MB
# [Tai100a] Seed 50 | rho=0.05 finalizada. Custo: 23906670 | Memória: 121.13 MB
# [Tai100a] Seed 51 | rho=0.05 finalizada. Custo: 23990386 | Memória: 121.13 MB
#
# Resultados da instância Tai100a salvos em resultados_Tai100a_ACO_10min.csv
# [Tai100b] Seed 42 | rho=0.05 finalizada. Custo: 1755874092 | Memória: 122.27 MB
# [Tai100b] Seed 43 | rho=0.05 finalizada. Custo: 1739150244 | Memória: 122.27 MB
# [Tai100b] Seed 44 | rho=0.05 finalizada. Custo: 1724360257 | Memória: 122.27 MB
# [Tai100b] Seed 45 | rho=0.05 finalizada. Custo: 1712409769 | Memória: 122.27 MB
# [Tai100b] Seed 46 | rho=0.05 finalizada. Custo: 1719899284 | Memória: 122.33 MB
# [Tai100b] Seed 47 | rho=0.05 finalizada. Custo: 1744660648 | Memória: 122.34 MB
# [Tai100b] Seed 48 | rho=0.05 finalizada. Custo: 1685392886 | Memória: 122.34 MB
# [Tai100b] Seed 49 | rho=0.05 finalizada. Custo: 1743296363 | Memória: 122.34 MB
# [Tai100b] Seed 50 | rho=0.05 finalizada. Custo: 1730410059 | Memória: 122.34 MB
# [Tai100b] Seed 51 | rho=0.05 finalizada. Custo: 1747587868 | Memória: 122.34 MB
#
# Resultados da instância Tai100b salvos em resultados_Tai100b_ACO_10min.csv
# [Tai150b] Seed 42 | rho=0.05 finalizada. Custo: 645169045 | Memória: 122.34 MB
# [Tai150b] Seed 43 | rho=0.05 finalizada. Custo: 640318140 | Memória: 122.34 MB
# [Tai150b] Seed 44 | rho=0.05 finalizada. Custo: 649626915 | Memória: 122.34 MB
# [Tai150b] Seed 45 | rho=0.05 finalizada. Custo: 641034720 | Memória: 122.34 MB
# [Tai150b] Seed 46 | rho=0.05 finalizada. Custo: 639065191 | Memória: 122.34 MB
# [Tai150b] Seed 47 | rho=0.05 finalizada. Custo: 633705362 | Memória: 122.34 MB
# [Tai150b] Seed 48 | rho=0.05 finalizada. Custo: 640153369 | Memória: 122.34 MB
# [Tai150b] Seed 49 | rho=0.05 finalizada. Custo: 646995268 | Memória: 122.34 MB
# [Tai150b] Seed 50 | rho=0.05 finalizada. Custo: 643812354 | Memória: 122.34 MB
# [Tai150b] Seed 51 | rho=0.05 finalizada. Custo: 648809199 | Memória: 122.34 MB
#
# Resultados da instância Tai150b salvos em resultados_Tai150b_ACO_10min.csv
# [Tai256c] Seed 42 | rho=0.05 finalizada. Custo: 51619406 | Memória: 126.25 MB
# [Tai256c] Seed 43 | rho=0.05 finalizada. Custo: 51981078 | Memória: 126.25 MB
# [Tai256c] Seed 44 | rho=0.05 finalizada. Custo: 50956494 | Memória: 126.25 MB
# [Tai256c] Seed 45 | rho=0.05 finalizada. Custo: 50981412 | Memória: 126.25 MB
# [Tai256c] Seed 46 | rho=0.05 finalizada. Custo: 51771798 | Memória: 126.25 MB
# [Tai256c] Seed 47 | rho=0.05 finalizada. Custo: 52326684 | Memória: 126.25 MB
# [Tai256c] Seed 48 | rho=0.05 finalizada. Custo: 50833488 | Memória: 126.25 MB
# [Tai256c] Seed 49 | rho=0.05 finalizada. Custo: 52024554 | Memória: 126.25 MB
# [Tai256c] Seed 50 | rho=0.05 finalizada. Custo: 52008664 | Memória: 126.25 MB
# [Tai256c] Seed 51 | rho=0.05 finalizada. Custo: 52255680 | Memória: 126.25 MB
#
# Resultados da instância Tai256c salvos em resultados_Tai256c_ACO_10min.csv
# [Tai60a] Seed 42 | rho=0.05 finalizada. Custo: 8420538 | Memória: 126.25 MB
# [Tai60a] Seed 43 | rho=0.05 finalizada. Custo: 8383852 | Memória: 126.25 MB
# [Tai60a] Seed 44 | rho=0.05 finalizada. Custo: 8377746 | Memória: 126.25 MB
# [Tai60a] Seed 45 | rho=0.05 finalizada. Custo: 8384688 | Memória: 126.25 MB
# [Tai60a] Seed 46 | rho=0.05 finalizada. Custo: 8409946 | Memória: 126.25 MB
# [Tai60a] Seed 47 | rho=0.05 finalizada. Custo: 8427512 | Memória: 126.25 MB
# [Tai60a] Seed 48 | rho=0.05 finalizada. Custo: 8440836 | Memória: 126.25 MB
# [Tai60a] Seed 49 | rho=0.05 finalizada. Custo: 8430172 | Memória: 126.25 MB
# [Tai60a] Seed 50 | rho=0.05 finalizada. Custo: 8425126 | Memória: 126.25 MB
# [Tai60a] Seed 51 | rho=0.05 finalizada. Custo: 8388540 | Memória: 126.25 MB
#
# Resultados da instância Tai60a salvos em resultados_Tai60a_ACO_10min.csv
# [Tai60b] Seed 42 | rho=0.05 finalizada. Custo: 968980572 | Memória: 126.25 MB
# [Tai60b] Seed 43 | rho=0.05 finalizada. Custo: 993878494 | Memória: 126.25 MB
# [Tai60b] Seed 44 | rho=0.05 finalizada. Custo: 918113916 | Memória: 126.25 MB
# [Tai60b] Seed 45 | rho=0.05 finalizada. Custo: 931563747 | Memória: 126.25 MB
# [Tai60b] Seed 46 | rho=0.05 finalizada. Custo: 926607636 | Memória: 126.25 MB
# [Tai60b] Seed 47 | rho=0.05 finalizada. Custo: 997264205 | Memória: 126.25 MB
# [Tai60b] Seed 48 | rho=0.05 finalizada. Custo: 942055372 | Memória: 126.25 MB
# [Tai60b] Seed 49 | rho=0.05 finalizada. Custo: 952048005 | Memória: 126.25 MB
# [Tai60b] Seed 50 | rho=0.05 finalizada. Custo: 962894672 | Memória: 126.25 MB
# [Tai60b] Seed 51 | rho=0.05 finalizada. Custo: 980014263 | Memória: 126.25 MB
#
# Resultados da instância Tai60b salvos em resultados_Tai60b_ACO_10min.csv
# [Tai64c] Seed 42 | rho=0.05 finalizada. Custo: 2379924 | Memória: 126.25 MB
# [Tai64c] Seed 43 | rho=0.05 finalizada. Custo: 2454104 | Memória: 126.25 MB
# [Tai64c] Seed 44 | rho=0.05 finalizada. Custo: 2312726 | Memória: 126.25 MB
# [Tai64c] Seed 45 | rho=0.05 finalizada. Custo: 2448080 | Memória: 126.25 MB
# [Tai64c] Seed 46 | rho=0.05 finalizada. Custo: 2444964 | Memória: 126.25 MB
# [Tai64c] Seed 47 | rho=0.05 finalizada. Custo: 2449680 | Memória: 126.25 MB
# [Tai64c] Seed 48 | rho=0.05 finalizada. Custo: 2476032 | Memória: 126.25 MB
# [Tai64c] Seed 49 | rho=0.05 finalizada. Custo: 2459986 | Memória: 126.25 MB
# [Tai64c] Seed 50 | rho=0.05 finalizada. Custo: 2569642 | Memória: 126.25 MB
# [Tai64c] Seed 51 | rho=0.05 finalizada. Custo: 2387260 | Memória: 126.25 MB
#
# Resultados da instância Tai64c salvos em resultados_Tai64c_ACO_10min.csv
# [Tai80a] Seed 42 | rho=0.05 finalizada. Custo: 15479208 | Memória: 126.25 MB
# [Tai80a] Seed 43 | rho=0.05 finalizada. Custo: 15482970 | Memória: 126.25 MB
# [Tai80a] Seed 44 | rho=0.05 finalizada. Custo: 15470084 | Memória: 126.25 MB
# [Tai80a] Seed 45 | rho=0.05 finalizada. Custo: 15467164 | Memória: 126.25 MB
# [Tai80a] Seed 46 | rho=0.05 finalizada. Custo: 15500036 | Memória: 126.25 MB
# [Tai80a] Seed 47 | rho=0.05 finalizada. Custo: 15541900 | Memória: 126.25 MB
# [Tai80a] Seed 48 | rho=0.05 finalizada. Custo: 15435226 | Memória: 126.25 MB
# [Tai80a] Seed 49 | rho=0.05 finalizada. Custo: 15456566 | Memória: 126.25 MB
# [Tai80a] Seed 50 | rho=0.05 finalizada. Custo: 15484922 | Memória: 126.25 MB
# [Tai80a] Seed 51 | rho=0.05 finalizada. Custo: 15446302 | Memória: 126.25 MB
#
# Resultados da instância Tai80a salvos em resultados_Tai80a_ACO_10min.csv
# [Tho150] Seed 42 | rho=0.05 finalizada. Custo: 9846252 | Memória: 126.25 MB
# [Tho150] Seed 43 | rho=0.05 finalizada. Custo: 9630394 | Memória: 126.25 MB
# [Tho150] Seed 44 | rho=0.05 finalizada. Custo: 9773970 | Memória: 126.25 MB
# [Tho150] Seed 45 | rho=0.05 finalizada. Custo: 9813338 | Memória: 126.25 MB
# [Tho150] Seed 46 | rho=0.05 finalizada. Custo: 9793118 | Memória: 126.25 MB
# [Tho150] Seed 47 | rho=0.05 finalizada. Custo: 9836074 | Memória: 126.25 MB
# [Tho150] Seed 48 | rho=0.05 finalizada. Custo: 9874216 | Memória: 126.25 MB
# [Tho150] Seed 49 | rho=0.05 finalizada. Custo: 9812844 | Memória: 126.25 MB
# [Tho150] Seed 50 | rho=0.05 finalizada. Custo: 9764066 | Memória: 126.25 MB
# [Tho150] Seed 51 | rho=0.05 finalizada. Custo: 9847906 | Memória: 126.25 MB
#
# Resultados da instância Tho150 salvos em resultados_Tho150_ACO_10min.csv
# [Tho30] Seed 42 | rho=0.05 finalizada. Custo: 215900 | Memória: 126.25 MB
# [Tho30] Seed 43 | rho=0.05 finalizada. Custo: 207276 | Memória: 126.25 MB
# [Tho30] Seed 44 | rho=0.05 finalizada. Custo: 218514 | Memória: 126.25 MB
# [Tho30] Seed 45 | rho=0.05 finalizada. Custo: 214328 | Memória: 126.25 MB
# [Tho30] Seed 46 | rho=0.05 finalizada. Custo: 216196 | Memória: 126.25 MB
# [Tho30] Seed 47 | rho=0.05 finalizada. Custo: 214588 | Memória: 126.25 MB
# [Tho30] Seed 48 | rho=0.05 finalizada. Custo: 206464 | Memória: 126.25 MB
# [Tho30] Seed 49 | rho=0.05 finalizada. Custo: 209940 | Memória: 126.25 MB
# [Tho30] Seed 50 | rho=0.05 finalizada. Custo: 209612 | Memória: 126.25 MB
# [Tho30] Seed 51 | rho=0.05 finalizada. Custo: 214980 | Memória: 126.25 MB
#
# Resultados da instância Tho30 salvos em resultados_Tho30_ACO_10min.csv
# [Tho40] Seed 42 | rho=0.05 finalizada. Custo: 332190 | Memória: 126.25 MB
# [Tho40] Seed 43 | rho=0.05 finalizada. Custo: 338836 | Memória: 126.25 MB
# [Tho40] Seed 44 | rho=0.05 finalizada. Custo: 329060 | Memória: 126.25 MB
# [Tho40] Seed 45 | rho=0.05 finalizada. Custo: 328134 | Memória: 126.25 MB
# [Tho40] Seed 46 | rho=0.05 finalizada. Custo: 331880 | Memória: 126.25 MB
# [Tho40] Seed 47 | rho=0.05 finalizada. Custo: 333170 | Memória: 126.25 MB
# [Tho40] Seed 48 | rho=0.05 finalizada. Custo: 340080 | Memória: 126.25 MB
# [Tho40] Seed 49 | rho=0.05 finalizada. Custo: 344274 | Memória: 126.25 MB
# [Tho40] Seed 50 | rho=0.05 finalizada. Custo: 337168 | Memória: 126.25 MB
# [Tho40] Seed 51 | rho=0.05 finalizada. Custo: 319716 | Memória: 126.25 MB
#
# Resultados da instância Tho40 salvos em resultados_Tho40_ACO_10min.csv
# [Wil100] Seed 42 | rho=0.05 finalizada. Custo: 301504 | Memória: 126.25 MB
# [Wil100] Seed 43 | rho=0.05 finalizada. Custo: 301810 | Memória: 126.25 MB
# [Wil100] Seed 44 | rho=0.05 finalizada. Custo: 302360 | Memória: 126.25 MB
# [Wil100] Seed 45 | rho=0.05 finalizada. Custo: 302862 | Memória: 126.25 MB
# [Wil100] Seed 46 | rho=0.05 finalizada. Custo: 301542 | Memória: 126.25 MB
# [Wil100] Seed 47 | rho=0.05 finalizada. Custo: 300536 | Memória: 126.25 MB
# [Wil100] Seed 48 | rho=0.05 finalizada. Custo: 301430 | Memória: 126.25 MB
# [Wil100] Seed 49 | rho=0.05 finalizada. Custo: 301850 | Memória: 126.25 MB
# [Wil100] Seed 50 | rho=0.05 finalizada. Custo: 301326 | Memória: 126.25 MB
# [Wil100] Seed 51 | rho=0.05 finalizada. Custo: 302050 | Memória: 126.25 MB
#
# Resultados da instância Wil100 salvos em resultados_Wil100_ACO_10min.csv
# [Wil50] Seed 42 | rho=0.05 finalizada. Custo: 56008 | Memória: 126.25 MB
# [Wil50] Seed 43 | rho=0.05 finalizada. Custo: 56140 | Memória: 126.25 MB
# [Wil50] Seed 44 | rho=0.05 finalizada. Custo: 56026 | Memória: 126.25 MB
# [Wil50] Seed 45 | rho=0.05 finalizada. Custo: 56484 | Memória: 126.25 MB
# [Wil50] Seed 46 | rho=0.05 finalizada. Custo: 56720 | Memória: 126.25 MB
# [Wil50] Seed 47 | rho=0.05 finalizada. Custo: 55748 | Memória: 126.25 MB
# [Wil50] Seed 48 | rho=0.05 finalizada. Custo: 56096 | Memória: 126.25 MB
# [Wil50] Seed 49 | rho=0.05 finalizada. Custo: 55502 | Memória: 126.25 MB
# [Wil50] Seed 50 | rho=0.05 finalizada. Custo: 56090 | Memória: 126.25 MB
# [Wil50] Seed 51 | rho=0.05 finalizada. Custo: 55710 | Memória: 126.25 MB
#
# Resultados da instância Wil50 salvos em resultados_Wil50_ACO_10min.csv
